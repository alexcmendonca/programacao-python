# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo 02** | Python: Estruturas de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Listas;</li>
#   <li>Conjuntos;</li>
#   <li>Dicionários.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Listas

# %% [markdown]
# Criei uma lista chamada `filmes` com o nome dos 10 primeiros filmes mais bem avaliados no site no [IMDB](https://www.imdb.com/chart/top/). Imprima o resultado.

# %%
filmes = ['Um Sonho de Liberdade' , 'O Poderoso Chefão', 'Batman: O Cavaleiro das Trevas' , 'O Poderoso Chefão II' , '12 Homens e uma Sentença' , 'A Lista de Schindler' , 'O Senhor dos Anéis: O Retorno do Rei' , 'Pulp Fiction: Tempo de Violência' , 'O Senhor dos Anéis: A Sociedade do Anel' , 'Três Homens em Conflito']
print(filmes)
# Out:
# ['Um Sonho de Liberdade', 'O Poderoso Chefão', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']

# %% [markdown]
# Simule a movimentação do *ranking*. Utilize os métodos `insert` e `pop` para trocar a posição do primeiro e do segundo filme da lista. Imprima o resultado.

# %%
# removendo o filme da primeira posição no ranking
update_ranking = filmes.pop(0)
print(filmes)
# Out:
# ['O Poderoso Chefão', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']

# %%
# atualizando ranking atualizando filme na segunda posição
filmes.insert(1, 'Um Sonho de Liberdade')
print(filmes)
# Out:
# ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Conjuntos

# %% [markdown]
# Aconteceu um erro no seu *ranking*. Simule a duplicação dos três últimos filmes da lista. Imprima o resultado.

# %% [markdown]
# Utiliza a conversão `set` e `list` para remover os valores duplicados. Imprima o resultado.

# %%
# atualizando ranking "de forma equivocada" duplicando o filme
filmes.insert(len(filmes), 'Pulp Fiction: Tempo de Violência')
print(filmes)
print(len(filmes))
# Out:
# ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito', 'Pulp Fiction: Tempo de Violência']
# 11

# %%
# atualizando ranking "de forma equivocada" duplicando o filme
filmes.append('O Senhor dos Anéis: A Sociedade do Anel')
print(filmes)
print(len(filmes))
# Out:
# ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel']
# 12

# %%
filmes.insert(10, 'Três Homens em Conflito')
print(filmes)
print(len(filmes))
# Out:
# ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito', 'Três Homens em Conflito', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel']
# 13

# %%
filmes = list(set(filmes))
print(filmes)
print(len(filmes))
# Out:
# ['Batman: O Cavaleiro das Trevas', 'Pulp Fiction: Tempo de Violência', 'O Poderoso Chefão', 'A Lista de Schindler', 'O Poderoso Chefão II', 'Um Sonho de Liberdade', 'Três Homens em Conflito', '12 Homens e uma Sentença', 'O Senhor dos Anéis: O Retorno do Rei', 'O Senhor dos Anéis: A Sociedade do Anel']
# 10

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Dicionários

# %% [markdown]
# Repita os exercícios da parte 1 (listas). Os elementos da lista `filmes` devem ser dicionários no seguinte formato: `{'nome': <nome-do-filme>, 'ano': <ano do filme>}, 'sinopse': <sinopse do filme>}`.

# %%
filmes = []

ranking = {
    'nome': 'Um Sonho de Liberdade',
    'ano': 1994,
    'sinopse': 'Dois homens presos se reúnem ao longo de vários anos...'
}
filmes.append(ranking)

ranking = {
    'nome': 'O Poderoso Chefão',
    'ano': 1972,
    'sinopse': 'O patriarca idoso de uma dinastia do crime organizado'
}
filmes.append(ranking)

ranking = {
    'nome': 'Batman: O Cavaleiro das Trevas',
    'ano': 2008,
    'sinopse': 'Quando a ameaça conhecida como O Coringa'
}
filmes.append(ranking)
ranking = {
    'nome': 'O Poderoso Chefão II',
    'ano': 1974,
    'sinopse': 'Dois homens presos se reúnem ao longo de vários anos...'
}
filmes.append(ranking)
ranking = {
    'nome': '12 Homens e uma Sentença',
    'ano': 1957,
    'sinopse': 'O julgamento de um assassinato em Nova Iorque é frustrado'
}
filmes.append(ranking)
ranking = {
    'nome': 'A Lista de Schindler',
    'ano': 1993,
    'sinopse': 'Na Polônia ocupada pelos alemães durante a Segunda Guerra Mundial'
}
filmes.append(ranking)
ranking = {
    'nome': 'O Senhor dos Anéis: O Retorno do Rei',
    'ano': 2003,
    'sinopse': 'Gandalf e Aragorn lideram o Mundo dos Homens contra o exército de Sauron'
}
filmes.append(ranking)
ranking = {
    'nome': 'Pulp Fiction: Tempo de Violência',
    'ano': 1994,
    'sinopse': 'As vidas de dois assassinos da máfia, um boxeador, um gângster e sua esposa'
}
filmes.append(ranking)
ranking = {
    'nome': 'O Senhor dos Anéis: A Sociedade do Anel',
    'ano': 2001,
    'sinopse': 'Um manso hobbit do Condado e oito companheiros partem em uma jornada'
}
filmes.append(ranking)
ranking = {
    'nome': 'Três Homens em Conflito',
    'ano': 1966,
    'sinopse': 'Um impostor se junta com dois homens para encontrar fortuna num remoto'
}
filmes.append(ranking)
print(filmes)
print(len(filmes))
print(type(filmes))
# Out:
# [{'nome': 'Um Sonho de Liberdade', 'ano': 1994, 'sinopse': 'Dois homens presos se reúnem ao longo de vários anos...'}, {'nome': 'O Poderoso Chefão', 'ano': 1972, 'sinopse': 'O patriarca idoso de uma dinastia do crime organizado'}, {'nome': 'Batman: O Cavaleiro das Trevas', 'ano': 2008, 'sinopse': 'Quando a ameaça conhecida como O Coringa'}, {'nome': 'O Poderoso Chefão II', 'ano': 1974, 'sinopse': 'Dois homens presos se reúnem ao longo de vários anos...'}, {'nome': '12 Homens e uma Sentença', 'ano': 1957, 'sinopse': 'O julgamento de um assassinato em Nova Iorque é frustrado'}, {'nome': 'A Lista de Schindler', 'ano': 1993, 'sinopse': 'Na Polônia ocupada pelos alemães durante a Segunda Guerra Mundial'}, {'nome': 'O Senhor dos Anéis: O Retorno do Rei', 'ano': 2003, 'sinopse': 'Gandalf e Aragorn lideram o Mundo dos Homens contra o exército de Sauron'}, {'nome': 'Pulp Fiction: Tempo de Violência', 'ano': 1994, 'sinopse': 'As vidas de dois assassinos da máfia, um boxeador, um gângster e sua
# ...
